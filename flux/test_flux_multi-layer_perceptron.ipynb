# %%
using Flux, Statistics
using Flux.Data: DataLoader
using Flux: onehotbatch, onecold, logitcrossentropy, throttle, @epochs
using Base.Iterators: repeated
using Parameters: @with_kw
using CUDAapi
using MLDatasets
if has_cuda()  # Check if CUDA is available
    @info "CUDA is on"
    import CuArrays  # If CUDA is available, import CuArrays
    CuArrays.allowscalar(false)
end

# %%
@with_kw mutable struct Args
    η::Float64 = 3e-4       # learning rate
    batchsize::Int = 1024   # batch size
    epochs::Int = 10        # number of epochs
    device::Function = gpu  # set as gpu, if gpu available
end
# Out:
# Args

# %%
function getdata(args)
    # Loading Dataset
    xtrain, ytrain = MLDatasets.MNIST.traindata(Float32)
    xtest, ytest = MLDatasets.MNIST.testdata(Float32)

    # Reshape Data for flatten the each image into linear array
    xtrain = Flux.flatten(xtrain)
    xtest = Flux.flatten(xtest)

    # One-hot-encode the labels
    ytrain, ytest = onehotbatch(ytrain, 0:9), onehotbatch(ytest, 0:9)

    # Batching
    train_data = DataLoader(xtrain, ytrain, batchsize=args.batchsize, shuffle=true)
    test_data = DataLoader(xtest, ytest, batchsize=args.batchsize)

    return train_data, test_data
end
# Out:
# getdata (generic function with 1 method)

# %%
function build_model(; imgsize=(28,28,1), nclasses=10)
    return Chain(
            Dense(prod(imgsize), 32, relu),
            Dense(32, nclasses))
end
# Out:
# build_model (generic function with 1 method)

# %%
function loss_all(dataloader, model)
    l = 0f0
    for (x,y) in dataloader
        l += logitcrossentropy(model(x), y)
    end
    l/length(dataloader)
end
# Out:
# loss_all (generic function with 1 method)

# %%
function accuracy(data_loader, model)
    acc = 0
    for (x,y) in data_loader
        acc += sum(onecold(cpu(model(x))) .== onecold(cpu(y)))*1 / size(x,2)
    end
    acc/length(data_loader)
end
# Out:
# accuracy (generic function with 1 method)

# %%
function train(; kws...)
    # Initializing Model parameters 
    args = Args(; kws...)

    # Load Data
    train_data,test_data = getdata(args)

    # Construct model
    m = build_model()
    train_data = args.device.(train_data)
    test_data = args.device.(train_data)
    m = args.device(m)
    loss(x,y) = logitcrossentropy(m(x), y)
    
    ## Training
    evalcb = () -> @show(loss_all(train_data, m))
    opt = ADAM(args.η)

    @epochs args.epochs Flux.train!(loss, params(m), train_data, opt, cb = evalcb)

    @show accuracy(train_data, m)

    @show accuracy(test_data, m)
end
# Out:
# train (generic function with 1 method)

# %%
cd(@__DIR__)
train()
# Out:
# ┌ Info: Epoch 1
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# loss_all(train_data, m) = 2.2981153f0
# loss_all(train_data, m) = 2.2775574f0
# loss_all(train_data, m) = 2.257917f0
# loss_all(train_data, m) = 2.2389674f0
# loss_all(train_data, m) = 2.2206185f0
# loss_all(train_data, m) = 2.2027218f0
# loss_all(train_data, m) = 2.185217f0
# loss_all(train_data, m) = 2.1680458f0
# loss_all(train_data, m) = 2.151162f0
# loss_all(train_data, m) = 2.1345675f0
# loss_all(train_data, m) = 2.118097f0
# loss_all(train_data, m) = 2.101754f0
# loss_all(train_data, m) = 2.0854404f0
# loss_all(train_data, m) = 2.0692234f0
# loss_all(train_data, m) = 2.0530176f0
# loss_all(train_data, m) = 2.0368364f0
# loss_all(train_data, m) = 2.020643f0
# loss_all(train_data, m) = 2.0044088f0
# loss_all(train_data, m) = 1.988065f0
# loss_all(train_data, m) = 1.9716523f0
# loss_all(train_data, m) = 1.9551747f0
# loss_all(train_data, m) = 1.9386064f0
# loss_all(train_data, m) = 1.9219378f0
# loss_all(train_data, m) = 1.9051024f0
# loss_all(train_data, m) = 1.8881837f0
# loss_all(train_data, m) = 1.8712518f0
# loss_all(train_data, m) = 1.8542126f0
# loss_all(train_data, m) = 1.8371563f0
# loss_all(train_data, m) = 1.8200533f0
# loss_all(train_data, m) = 1.8029265f0
# loss_all(train_data, m) = 1.7857594f0
# loss_all(train_data, m) = 1.7685494f0
# loss_all(train_data, m) = 1.7513403f0
# loss_all(train_data, m) = 1.7342068f0
# loss_all(train_data, m) = 1.7171597f0
# loss_all(train_data, m) = 1.7002141f0
# loss_all(train_data, m) = 1.6833487f0
# loss_all(train_data, m) = 1.6666294f0
# loss_all(train_data, m) = 1.650022f0
# loss_all(train_data, m) = 1.6335186f0
# loss_all(train_data, m) = 1.6171358f0
# loss_all(train_data, m) = 1.6008409f0
# loss_all(train_data, m) = 1.5846957f0
# loss_all(train_data, m) = 1.5686568f0
# loss_all(train_data, m) = 1.5527954f0
# loss_all(train_data, m) = 1.537058f0
# loss_all(train_data, m) = 1.5214896f0
# loss_all(train_data, m) = 1.506087f0
# loss_all(train_data, m) = 1.4908746f0
# loss_all(train_data, m) = 1.4758253f0
# loss_all(train_data, m) = 1.4609195f0
# loss_all(train_data, m) = 1.4461654f0
# loss_all(train_data, m) = 1.4315548f0
# loss_all(train_data, m) = 1.4171774f0
# loss_all(train_data, m) = 1.4029913f0
# loss_all(train_data, m) = 1.3890067f0
# loss_all(train_data, m) = 1.3751477f0
# loss_all(train_data, m) = 1.3614104f0
# loss_all(train_data, m) = 1.3478235f0
# loss_all(train_data, m) = 1.3343823f0
# loss_all(train_data, m) =
# ┌ Info: Epoch 2
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# 1.3210677f0
# loss_all(train_data, m) = 1.3079668f0
# loss_all(train_data, m) = 1.2950487f0
# loss_all(train_data, m) = 1.282315f0
# loss_all(train_data, m) = 1.2697116f0
# loss_all(train_data, m) = 1.2572827f0
# loss_all(train_data, m) = 1.2450247f0
# loss_all(train_data, m) = 1.2329206f0
# loss_all(train_data, m) = 1.2209444f0
# loss_all(train_data, m) = 1.2091535f0
# loss_all(train_data, m) = 1.1975375f0
# loss_all(train_data, m) = 1.1860894f0
# loss_all(train_data, m) = 1.1748438f0
# loss_all(train_data, m) = 1.1637418f0
# loss_all(train_data, m) = 1.152799f0
# loss_all(train_data, m) = 1.142028f0
# loss_all(train_data, m) = 1.1314083f0
# loss_all(train_data, m) = 1.1209738f0
# loss_all(train_data, m) = 1.1107329f0
# loss_all(train_data, m) = 1.1006857f0
# loss_all(train_data, m) = 1.0907996f0
# loss_all(train_data, m) = 1.0811092f0
# loss_all(train_data, m) = 1.0715741f0
# loss_all(train_data, m) = 1.0622082f0
# loss_all(train_data, m) = 1.0530168f0
# loss_all(train_data, m) = 1.0439694f0
# loss_all(train_data, m) = 1.0350765f0
# loss_all(train_data, m) = 1.0263742f0
# loss_all(train_data, m) = 1.0178146f0
# loss_all(train_data, m) = 1.0093709f0
# loss_all(train_data, m) = 1.0010792f0
# loss_all(train_data, m) = 0.992935f0
# loss_all(train_data, m) = 0.9849335f0
# loss_all(train_data, m) = 0.97711194f0
# loss_all(train_data, m) = 0.9694365f0
# loss_all(train_data, m) = 0.9618744f0
# loss_all(train_data, m) = 0.9544448f0
# loss_all(train_data, m) = 0.94709295f0
# loss_all(train_data, m) = 0.93987185f0
# loss_all(train_data, m) = 0.9327998f0
# loss_all(train_data, m) = 0.92586386f0
# loss_all(train_data, m) = 0.9190128f0
# loss_all(train_data, m) = 0.91228837f0
# loss_all(train_data, m) = 0.90568286f0
# loss_all(train_data, m) = 0.8991755f0
# loss_all(train_data, m) = 0.892796f0
# loss_all(train_data, m) = 0.8865543f0
# loss_all(train_data, m) = 0.88046026f0
# loss_all(train_data, m) = 0.8744581f0
# loss_all(train_data, m) = 0.8685707f0
# loss_all(train_data, m) = 0.8627549f0
# loss_all(train_data, m) = 0.8570122f0
# loss_all(train_data, m) = 0.85139227f0
# loss_all(train_data, m) = 0.84587103f0
# loss_all(train_data, m) = 0.84044486f0
# loss_all(train_data, m) = 0.8350377f0
# loss_all(train_data, m) = 0.8296634f0
# loss_all(train_data, m) = 0.8243471f0
# loss_all(train_data, m) = 0.8191176f0
# loss_all(train_data, m) =
# ┌ Info: Epoch 3
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# 0.8139554f0
# loss_all(train_data, m) = 0.80894f0
# loss_all(train_data, m) = 0.8040557f0
# loss_all(train_data, m) = 0.7992726f0
# loss_all(train_data, m) = 0.79458195f0
# loss_all(train_data, m) = 0.7899621f0
# loss_all(train_data, m) = 0.7854078f0
# loss_all(train_data, m) = 0.7808892f0
# loss_all(train_data, m) = 0.77639186f0
# loss_all(train_data, m) = 0.77199864f0
# loss_all(train_data, m) = 0.76767606f0
# loss_all(train_data, m) = 0.76341987f0
# loss_all(train_data, m) = 0.7592529f0
# loss_all(train_data, m) = 0.75513333f0
# loss_all(train_data, m) = 0.7510213f0
# loss_all(train_data, m) = 0.7469472f0
# loss_all(train_data, m) = 0.74290544f0
# loss_all(train_data, m) = 0.7389348f0
# loss_all(train_data, m) = 0.7350334f0
# loss_all(train_data, m) = 0.73118407f0
# loss_all(train_data, m) = 0.72737044f0
# loss_all(train_data, m) = 0.7236196f0
# loss_all(train_data, m) = 0.719921f0
# loss_all(train_data, m) = 0.7162845f0
# loss_all(train_data, m) = 0.7126949f0
# loss_all(train_data, m) = 0.7091521f0
# loss_all(train_data, m) = 0.7056411f0
# loss_all(train_data, m) = 0.7021802f0
# loss_all(train_data, m) = 0.69873786f0
# loss_all(train_data, m) = 0.6953115f0
# loss_all(train_data, m) = 0.6919383f0
# loss_all(train_data, m) = 0.68860716f0
# loss_all(train_data, m) = 0.6853182f0
# loss_all(train_data, m) = 0.6820982f0
# loss_all(train_data, m) = 0.678932f0
# loss_all(train_data, m) = 0.6757994f0
# loss_all(train_data, m) = 0.6726984f0
# loss_all(train_data, m) = 0.6695978f0
# loss_all(train_data, m) = 0.6665407f0
# loss_all(train_data, m) = 0.6635455f0
# loss_all(train_data, m) = 0.660616f0
# loss_all(train_data, m) = 0.6576912f0
# loss_all(train_data, m) = 0.65481514f0
# loss_all(train_data, m) = 0.65196764f0
# loss_all(train_data, m) = 0.6491416f0
# loss_all(train_data, m) = 0.6463424f0
# loss_all(train_data, m) = 0.6435785f0
# loss_all(train_data, m) = 0.64087033f0
# loss_all(train_data, m) = 0.6382068f0
# loss_all(train_data, m) = 0.6355949f0
# loss_all(train_data, m) = 0.63300765f0
# loss_all(train_data, m) = 0.63044184f0
# loss_all(train_data, m) = 0.62793f0
# loss_all(train_data, m) = 0.6254501f0
# loss_all(train_data, m) = 0.62299407f0
# loss_all(train_data, m) = 0.62050474f0
# loss_all(train_data, m) = 0.6179983f0
# loss_all(train_data, m) = 0.6154961f0
# ┌ Info: Epoch 4
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# loss_all(train_data, m) = 0.61301637f0
# loss_all(train_data, m) = 0.61055875f0
# loss_all(train_data, m) = 0.60818744f0
# loss_all(train_data, m) = 0.6058846f0
# loss_all(train_data, m) = 0.6036269f0
# loss_all(train_data, m) = 0.6014101f0
# loss_all(train_data, m) = 0.5992038f0
# loss_all(train_data, m) = 0.59702855f0
# loss_all(train_data, m) = 0.59485626f0
# loss_all(train_data, m) = 0.59265184f0
# loss_all(train_data, m) = 0.59049815f0
# loss_all(train_data, m) = 0.58837587f0
# loss_all(train_data, m) = 0.5862844f0
# loss_all(train_data, m) = 0.584246f0
# loss_all(train_data, m) = 0.582225f0
# loss_all(train_data, m) = 0.580182f0
# loss_all(train_data, m) = 0.5781377f0
# loss_all(train_data, m) = 0.5760979f0
# loss_all(train_data, m) = 0.574087f0
# loss_all(train_data, m) = 0.5721044f0
# loss_all(train_data, m) = 0.5701434f0
# loss_all(train_data, m) = 0.56819487f0
# loss_all(train_data, m) = 0.5662806f0
# loss_all(train_data, m) = 0.5643926f0
# loss_all(train_data, m) = 0.5625468f0
# loss_all(train_data, m) = 0.5607171f0
# loss_all(train_data, m) = 0.558918f0
# loss_all(train_data, m) = 0.55712754f0
# loss_all(train_data, m) = 0.5553548f0
# loss_all(train_data, m) = 0.5535719f0
# loss_all(train_data, m) = 0.5517859f0
# loss_all(train_data, m) = 0.55002487f0
# loss_all(train_data, m) = 0.54827124f0
# loss_all(train_data, m) = 0.5465344f0
# loss_all(train_data, m) = 0.5448342f0
# loss_all(train_data, m) = 0.543167f0
# loss_all(train_data, m) = 0.54151386f0
# loss_all(train_data, m) = 0.5398652f0
# loss_all(train_data, m) = 0.53821355f0
# loss_all(train_data, m) = 0.53658634f0
# loss_all(train_data, m) = 0.5349909f0
# loss_all(train_data, m) = 0.5334354f0
# loss_all(train_data, m) = 0.5318786f0
# loss_all(train_data, m) = 0.53035057f0
# loss_all(train_data, m) = 0.52883106f0
# loss_all(train_data, m) = 0.5273192f0
# loss_all(train_data, m) = 0.5258035f0
# loss_all(train_data, m) = 0.5242854f0
# loss_all(train_data, m) = 0.52278453f0
# loss_all(train_data, m) = 0.5213104f0
# loss_all(train_data, m) = 0.519867f0
# loss_all(train_data, m) = 0.5184407f0
# loss_all(train_data, m) = 0.5170296f0
# loss_all(train_data, m) = 0.5156576f0
# loss_all(train_data, m) = 0.5143058f0
# loss_all(train_data, m) = 0.51296407f0
# loss_all(train_data, m) = 0.5115769f0
# loss_all(train_data, m) = 0.5101611f0
# loss_all(train_data, m) = 0.5087383f0
# loss_all(train_data, m) = 0.50731575f0
# loss_all(train_data, m) =
# ┌ Info: Epoch 5
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# 0.5059028f0
# loss_all(train_data, m) = 0.5045518f0
# loss_all(train_data, m) = 0.5032498f0
# loss_all(train_data, m) = 0.5019769f0
# loss_all(train_data, m) = 0.50073165f0
# loss_all(train_data, m) = 0.4994779f0
# loss_all(train_data, m) = 0.49825177f0
# loss_all(train_data, m) = 0.49702695f0
# loss_all(train_data, m) = 0.49575102f0
# loss_all(train_data, m) = 0.49450386f0
# loss_all(train_data, m) = 0.49326932f0
# loss_all(train_data, m) = 0.49204737f0
# loss_all(train_data, m) = 0.49086636f0
# loss_all(train_data, m) = 0.48969457f0
# loss_all(train_data, m) = 0.4884946f0
# loss_all(train_data, m) = 0.48728356f0
# loss_all(train_data, m) = 0.48607063f0
# loss_all(train_data, m) = 0.48486698f0
# loss_all(train_data, m) = 0.4836737f0
# loss_all(train_data, m) = 0.48249412f0
# loss_all(train_data, m) = 0.4813194f0
# loss_all(train_data, m) = 0.48017135f0
# loss_all(train_data, m) = 0.47904104f0
# loss_all(train_data, m) = 0.47794765f0
# loss_all(train_data, m) = 0.47686383f0
# loss_all(train_data, m) = 0.4758031f0
# loss_all(train_data, m) = 0.4747462f0
# loss_all(train_data, m) = 0.4736941f0
# loss_all(train_data, m) = 0.4726239f0
# loss_all(train_data, m) = 0.47154835f0
# loss_all(train_data, m) = 0.47048956f0
# loss_all(train_data, m) = 0.46942496f0
# loss_all(train_data, m) = 0.4683685f0
# loss_all(train_data, m) = 0.46733317f0
# loss_all(train_data, m) = 0.46632257f0
# loss_all(train_data, m) = 0.4653164f0
# loss_all(train_data, m) = 0.46430498f0
# loss_all(train_data, m) = 0.46329373f0
# loss_all(train_data, m) = 0.46230134f0
# loss_all(train_data, m) = 0.4613243f0
# loss_all(train_data, m) = 0.46037143f0
# loss_all(train_data, m) = 0.4594194f0
# loss_all(train_data, m) = 0.4584925f0
# loss_all(train_data, m) = 0.4575696f0
# loss_all(train_data, m) = 0.45665315f0
# loss_all(train_data, m) = 0.45572427f0
# loss_all(train_data, m) = 0.45477754f0
# loss_all(train_data, m) = 0.45382908f0
# loss_all(train_data, m) = 0.4528948f0
# loss_all(train_data, m) = 0.45197612f0
# loss_all(train_data, m) = 0.45107117f0
# loss_all(train_data, m) = 0.4501799f0
# loss_all(train_data, m) = 0.4493211f0
# loss_all(train_data, m) = 0.44847843f0
# loss_all(train_data, m) = 0.44764507f0
# loss_all(train_data, m) = 0.4467658f0
# loss_all(train_data, m) = 0.44585964f0
# loss_all(train_data, m) = 0.4449415f0
# ┌ Info: Epoch 6
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# loss_all(train_data, m) = 0.4440185f0
# loss_all(train_data, m) = 0.4430972f0
# loss_all(train_data, m) = 0.44222453f0
# loss_all(train_data, m) = 0.44138908f0
# loss_all(train_data, m) = 0.4405753f0
# loss_all(train_data, m) = 0.4397865f0
# loss_all(train_data, m) = 0.43898243f0
# loss_all(train_data, m) = 0.4382046f0
# loss_all(train_data, m) = 0.4374311f0
# loss_all(train_data, m) = 0.4365997f0
# loss_all(train_data, m) = 0.43578565f0
# loss_all(train_data, m) = 0.4349782f0
# loss_all(train_data, m) = 0.4341754f0
# loss_all(train_data, m) = 0.4334087f0
# loss_all(train_data, m) = 0.4326441f0
# loss_all(train_data, m) = 0.43184876f0
# loss_all(train_data, m) = 0.43103778f0
# loss_all(train_data, m) = 0.43022648f0
# loss_all(train_data, m) = 0.42941618f0
# loss_all(train_data, m) = 0.4286092f0
# loss_all(train_data, m) = 0.42781374f0
# loss_all(train_data, m) = 0.42702064f0
# loss_all(train_data, m) = 0.42625147f0
# loss_all(train_data, m) = 0.4254975f0
# loss_all(train_data, m) = 0.4247793f0
# loss_all(train_data, m) = 0.4240668f0
# loss_all(train_data, m) = 0.42336857f0
# loss_all(train_data, m) = 0.4226744f0
# loss_all(train_data, m) = 0.4219805f0
# loss_all(train_data, m) = 0.42126504f0
# loss_all(train_data, m) = 0.42054388f0
# loss_all(train_data, m) = 0.41983443f0
# loss_all(train_data, m) = 0.41911414f0
# loss_all(train_data, m) = 0.41839975f0
# loss_all(train_data, m) = 0.41769928f0
# loss_all(train_data, m) = 0.41701913f0
# loss_all(train_data, m) = 0.41634038f0
# loss_all(train_data, m) = 0.41565132f0
# loss_all(train_data, m) = 0.41496626f0
# loss_all(train_data, m) = 0.41429943f0
# loss_all(train_data, m) = 0.41363814f0
# loss_all(train_data, m) = 0.4129902f0
# loss_all(train_data, m) = 0.41234446f0
# loss_all(train_data, m) = 0.41172516f0
# loss_all(train_data, m) = 0.41110656f0
# loss_all(train_data, m) = 0.41049555f0
# loss_all(train_data, m) = 0.4098682f0
# loss_all(train_data, m) = 0.40921584f0
# loss_all(train_data, m) = 0.4085556f0
# loss_all(train_data, m) = 0.4079017f0
# loss_all(train_data, m) = 0.40725622f0
# loss_all(train_data, m) = 0.40662307f0
# loss_all(train_data, m) = 0.4060018f0
# loss_all(train_data, m) = 0.4054082f0
# loss_all(train_data, m) = 0.40482664f0
# loss_all(train_data, m) = 0.40425268f0
# loss_all(train_data, m) = 0.40363386f0
# loss_all(train_data, m) = 0.40299308f0
# loss_all(train_data, m) = 0.40234f0
# loss_all(train_data, m) = 0.4016813f0
# loss_all(train_data, m) =
# ┌ Info: Epoch 7
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# 0.4010238f0
# loss_all(train_data, m) = 0.40040827f0
# loss_all(train_data, m) = 0.39982337f0
# loss_all(train_data, m) = 0.3992564f0
# loss_all(train_data, m) = 0.39871255f0
# loss_all(train_data, m) = 0.3981482f0
# loss_all(train_data, m) = 0.3976123f0
# loss_all(train_data, m) = 0.39708227f0
# loss_all(train_data, m) = 0.39649406f0
# loss_all(train_data, m) = 0.39591444f0
# loss_all(train_data, m) = 0.39533764f0
# loss_all(train_data, m) = 0.3947617f0
# loss_all(train_data, m) = 0.39421895f0
# loss_all(train_data, m) = 0.39367354f0
# loss_all(train_data, m) = 0.39309356f0
# loss_all(train_data, m) = 0.39249423f0
# loss_all(train_data, m) = 0.3918971f0
# loss_all(train_data, m) = 0.39129636f0
# loss_all(train_data, m) = 0.39069796f0
# loss_all(train_data, m) = 0.39011168f0
# loss_all(train_data, m) = 0.38952753f0
# loss_all(train_data, m) = 0.3889674f0
# loss_all(train_data, m) = 0.38842198f0
# loss_all(train_data, m) = 0.38791177f0
# loss_all(train_data, m) = 0.3874065f0
# loss_all(train_data, m) = 0.38691065f0
# loss_all(train_data, m) = 0.38641807f0
# loss_all(train_data, m) = 0.38592383f0
# loss_all(train_data, m) = 0.3854061f0
# loss_all(train_data, m) = 0.38488227f0
# loss_all(train_data, m) = 0.38436803f0
# loss_all(train_data, m) = 0.38384083f0
# loss_all(train_data, m) = 0.38331914f0
# loss_all(train_data, m) = 0.38280895f0
# loss_all(train_data, m) = 0.38231587f0
# loss_all(train_data, m) = 0.38182223f0
# loss_all(train_data, m) = 0.3813151f0
# loss_all(train_data, m) = 0.38081217f0
# loss_all(train_data, m) = 0.38032597f0
# loss_all(train_data, m) = 0.37984145f0
# loss_all(train_data, m) = 0.37936613f0
# loss_all(train_data, m) = 0.37889636f0
# loss_all(train_data, m) = 0.37845358f0
# loss_all(train_data, m) = 0.37801236f0
# loss_all(train_data, m) = 0.37758175f0
# loss_all(train_data, m) = 0.3771308f0
# loss_all(train_data, m) = 0.37665161f0
# loss_all(train_data, m) = 0.3761613f0
# loss_all(train_data, m) = 0.37567142f0
# loss_all(train_data, m) = 0.37518665f0
# loss_all(train_data, m) = 0.374714f0
# loss_all(train_data, m) = 0.37425306f0
# loss_all(train_data, m) = 0.37381682f0
# loss_all(train_data, m) = 0.3733904f0
# loss_all(train_data, m) = 0.3729716f0
# loss_all(train_data, m) = 0.37251127f0
# loss_all(train_data, m) = 0.37203282f0
# loss_all(train_data, m) = 0.37153918f0
# loss_all(train_data, m) = 0.3710356f0
# loss_all(train_data, m) =
# ┌ Info: Epoch 8
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# 0.37053004f0
# loss_all(train_data, m) = 0.37005958f0
# loss_all(train_data, m) = 0.3696195f0
# loss_all(train_data, m) = 0.3691975f0
# loss_all(train_data, m) = 0.3687986f0
# loss_all(train_data, m) = 0.3683791f0
# loss_all(train_data, m) = 0.36798912f0
# loss_all(train_data, m) = 0.3676081f0
# loss_all(train_data, m) = 0.3671721f0
# loss_all(train_data, m) = 0.36673823f0
# loss_all(train_data, m) = 0.36630508f0
# loss_all(train_data, m) = 0.36586913f0
# loss_all(train_data, m) = 0.36546358f0
# loss_all(train_data, m) = 0.36505082f0
# loss_all(train_data, m) = 0.36460167f0
# loss_all(train_data, m) = 0.36413196f0
# loss_all(train_data, m) = 0.3636661f0
# loss_all(train_data, m) = 0.3631949f0
# loss_all(train_data, m) = 0.36272463f0
# loss_all(train_data, m) = 0.36226708f0
# loss_all(train_data, m) = 0.36180946f0
# loss_all(train_data, m) = 0.36137506f0
# loss_all(train_data, m) = 0.36095774f0
# loss_all(train_data, m) = 0.36057445f0
# loss_all(train_data, m) = 0.3601955f0
# loss_all(train_data, m) = 0.35982203f0
# loss_all(train_data, m) = 0.35945317f0
# loss_all(train_data, m) = 0.35907984f0
# loss_all(train_data, m) = 0.35868254f0
# loss_all(train_data, m) = 0.35827968f0
# loss_all(train_data, m) = 0.35788372f0
# loss_all(train_data, m) = 0.35747367f0
# loss_all(train_data, m) = 0.3570691f0
# loss_all(train_data, m) = 0.35667944f0
# loss_all(train_data, m) = 0.3563039f0
# loss_all(train_data, m) = 0.35592797f0
# loss_all(train_data, m) = 0.3555375f0
# loss_all(train_data, m) = 0.35515323f0
# loss_all(train_data, m) = 0.35478568f0
# loss_all(train_data, m) = 0.35441595f0
# loss_all(train_data, m) = 0.35405135f0
# loss_all(train_data, m) = 0.35369155f0
# loss_all(train_data, m) = 0.35335958f0
# loss_all(train_data, m) = 0.353027f0
# loss_all(train_data, m) = 0.35270578f0
# loss_all(train_data, m) = 0.3523642f0
# loss_all(train_data, m) = 0.35199255f0
# loss_all(train_data, m) = 0.35160944f0
# loss_all(train_data, m) = 0.3512203f0
# loss_all(train_data, m) = 0.35083693f0
# loss_all(train_data, m) = 0.3504669f0
# loss_all(train_data, m) = 0.35010916f0
# loss_all(train_data, m) = 0.34977388f0
# loss_all(train_data, m) = 0.3494484f0
# loss_all(train_data, m) = 0.34912774f0
# loss_all(train_data, m) = 0.34876722f0
# loss_all(train_data, m) = 0.3483898f0
# loss_all(train_data, m) = 0.34799424f0
# ┌ Info: Epoch 9
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# loss_all(train_data, m) = 0.34758905f0
# loss_all(train_data, m) = 0.34718093f0
# loss_all(train_data, m) = 0.34680343f0
# loss_all(train_data, m) = 0.34645495f0
# loss_all(train_data, m) = 0.34612507f0
# loss_all(train_data, m) = 0.34581918f0
# loss_all(train_data, m) = 0.34549105f0
# loss_all(train_data, m) = 0.3451957f0
# loss_all(train_data, m) = 0.34491035f0
# loss_all(train_data, m) = 0.344577f0
# loss_all(train_data, m) = 0.34424326f0
# loss_all(train_data, m) = 0.34390843f0
# loss_all(train_data, m) = 0.34356788f0
# loss_all(train_data, m) = 0.3432545f0
# loss_all(train_data, m) = 0.34292975f0
# loss_all(train_data, m) = 0.34256428f0
# loss_all(train_data, m) = 0.3421744f0
# loss_all(train_data, m) = 0.3417915f0
# loss_all(train_data, m) = 0.34140337f0
# loss_all(train_data, m) = 0.34101942f0
# loss_all(train_data, m) = 0.34064895f0
# loss_all(train_data, m) = 0.3402781f0
# loss_all(train_data, m) = 0.3399288f0
# loss_all(train_data, m) = 0.33959642f0
# loss_all(train_data, m) = 0.33929637f0
# loss_all(train_data, m) = 0.33899984f0
# loss_all(train_data, m) = 0.33870676f0
# loss_all(train_data, m) = 0.33841974f0
# loss_all(train_data, m) = 0.33812478f0
# loss_all(train_data, m) = 0.3378058f0
# loss_all(train_data, m) = 0.33748358f0
# loss_all(train_data, m) = 0.33716762f0
# loss_all(train_data, m) = 0.33683914f0
# loss_all(train_data, m) = 0.33651575f0
# loss_all(train_data, m) = 0.33620712f0
# loss_all(train_data, m) = 0.33591017f0
# loss_all(train_data, m) = 0.33561292f0
# loss_all(train_data, m) = 0.33529815f0
# loss_all(train_data, m) = 0.33499032f0
# loss_all(train_data, m) = 0.33469933f0
# loss_all(train_data, m) = 0.33440372f0
# loss_all(train_data, m) = 0.33411053f0
# loss_all(train_data, m) = 0.33382443f0
# loss_all(train_data, m) = 0.3335656f0
# loss_all(train_data, m) = 0.33330667f0
# loss_all(train_data, m) = 0.33306193f0
# loss_all(train_data, m) = 0.33279642f0
# loss_all(train_data, m) = 0.33250168f0
# loss_all(train_data, m) = 0.33219525f0
# loss_all(train_data, m) = 0.33187878f0
# loss_all(train_data, m) = 0.33156785f0
# loss_all(train_data, m) = 0.33126953f0
# loss_all(train_data, m) = 0.33098167f0
# loss_all(train_data, m) = 0.33070955f0
# loss_all(train_data, m) = 0.3304438f0
# loss_all(train_data, m) = 0.3301815f0
# loss_all(train_data, m) = 0.32988387f0
# loss_all(train_data, m) = 0.32957467f0
# loss_all(train_data, m) = 0.3292481f0
# ┌ Info: Epoch 10
# └ @ Main /Users/yasu/.julia/packages/Flux/Fj3bt/src/optimise/train.jl:121
# loss_all(train_data, m) = 0.32891357f0
# loss_all(train_data, m) = 0.32857573f0
# loss_all(train_data, m) = 0.3282662f0
# loss_all(train_data, m) = 0.32798526f0
# loss_all(train_data, m) = 0.32772344f0
# loss_all(train_data, m) = 0.32748604f0
# loss_all(train_data, m) = 0.32722554f0
# loss_all(train_data, m) = 0.32699957f0
# loss_all(train_data, m) = 0.3267869f0
# loss_all(train_data, m) = 0.32652876f0
# loss_all(train_data, m) = 0.32626396f0
# loss_all(train_data, m) = 0.3259951f0
# loss_all(train_data, m) = 0.325717f0
# loss_all(train_data, m) = 0.32546526f0
# loss_all(train_data, m) = 0.32519805f0
# loss_all(train_data, m) = 0.32488668f0
# loss_all(train_data, m) = 0.32454887f0
# loss_all(train_data, m) = 0.3242214f0
# loss_all(train_data, m) = 0.32389003f0
# loss_all(train_data, m) = 0.32356456f0
# loss_all(train_data, m) = 0.32325408f0
# loss_all(train_data, m) = 0.32294258f0
# loss_all(train_data, m) = 0.3226528f0
# loss_all(train_data, m) = 0.3223817f0
# loss_all(train_data, m) = 0.3221424f0
# loss_all(train_data, m) = 0.3219048f0
# loss_all(train_data, m) = 0.32166755f0
# loss_all(train_data, m) = 0.32143646f0
# loss_all(train_data, m) = 0.32119435f0
# loss_all(train_data, m) = 0.32092726f0
# loss_all(train_data, m) = 0.3206589f0
# loss_all(train_data, m) = 0.32039565f0
# loss_all(train_data, m) = 0.3201194f0
# loss_all(train_data, m) = 0.31984982f0
# loss_all(train_data, m) = 0.31959754f0
# loss_all(train_data, m) = 0.3193564f0
# loss_all(train_data, m) = 0.31911454f0
# loss_all(train_data, m) = 0.31885332f0
# loss_all(train_data, m) = 0.31860015f0
# loss_all(train_data, m) = 0.31836265f0
# loss_all(train_data, m) = 0.31811613f0
# loss_all(train_data, m) = 0.3178675f0
# loss_all(train_data, m) = 0.31762862f0
# loss_all(train_data, m) = 0.31741592f0
# loss_all(train_data, m) = 0.31720546f0
# loss_all(train_data, m) = 0.31701234f0
# loss_all(train_data, m) = 0.31679872f0
# loss_all(train_data, m) = 0.31655937f0
# loss_all(train_data, m) = 0.3163095f0
# loss_all(train_data, m) = 0.31604782f0
# loss_all(train_data, m) = 0.31579053f0
# loss_all(train_data, m) = 0.31554446f0
# loss_all(train_data, m) = 0.3153066f0
# loss_all(train_data, m) = 0.31508213f0
# loss_all(train_data, m) = 0.31485936f0
# loss_all(train_data, m) = 0.31463677f0
# loss_all(train_data, m) = 0.31438342f0
# loss_all(train_data, m) = 0.31412265f0
# loss_all(train_data, m) = 0.3138434f0
# accuracy(train_data, m) = 0.9150939451382695
# accuracy(test_data, m) = 0.9150939451382695
# 0.9150939451382695
